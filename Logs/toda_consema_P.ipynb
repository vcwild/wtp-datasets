# %%
import numpy as np 
import pandas as pd 
from os import listdir
from shutil import copy2 

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
path = "./Dataset/"
word = "toda_consema_P"
archives = listdir(path) 

matches = [value for value in archives if word in value]
matches = sorted(matches)
matches
# Out:
# ['toda_consema_P7_2015.csv',
#  'toda_consema_P7_2016.csv',
#  'toda_consema_P7_2017.csv',
#  'toda_consema_P7_2018.csv',
#  'toda_consema_P7_2019.csv']

# %%
df = pd.DataFrame()
for i in range(0, len(matches) - 1):
    df_1 = pd.read_csv(path + matches[i], encoding='utf8')
    df_2 = pd.read_csv(path + matches[i + 1], encoding='utf8')
    partial = df_1.append(df_2)
    df = df.append(partial)

df
# Out:
#   PARÂMETROS        Data  Alumínio Total Arsênio Total Bário Total Boro Total  \
# 0  P7         2015-01-01  4.980           10            104         37.2
# 1  P7         2015-04-01  0.870           10            55          92
# 2  P7         2015-07-01  5.760           10            61          77.3
# 3  P7         2015-10-01  0.405           <0,01         0.0194      0.0142
# 0  P7         2016-01-01  0.624           <0,010        0.036       <0,050
# 1  P7         2016-04-01  1.510           <0,010        <0,010      <0,050
# 2  P7         2016-07-01  0.211           <0,010        0.032       <0,050
# 3  P7         2016-10-01  1.330           <0,010        0.019       <0,050
# 0  P7         2016-01-01  0.624           <0,010        0.036       <0,050
# 1  P7         2016-04-01  1.510           <0,010        <0,010      <0,050
# 2  P7         2016-07-01  0.211           <0,010        0.032       <0,050
# 3  P7         2016-10-01  1.330           <0,010        0.019       <0,050
# 0  P7         2017-01-01  0.947           < 0,010       < 0,010     < 0,050
# 1  P7         2017-04-01  1.429           < 0,010       0.083       < 0,050
# 2  P7         2017-07-01  3.416           <0,010        0.099       0.227
# 3  P7         2017-10-01  0.694           < 0,010       0.073       0.075
# 0  P7         2017-01-01  0.947           < 0,010       < 0,010     < 0,050
# 1  P7         2017-04-01  1.429           < 0,010       0.083       < 0,050
# 2  P7         2017-07-01  3.416           <0,010        0.099       0.227
# 3  P7         2017-10-01  0.694           < 0,010       0.073       0.075
# 0  P7         2018-01-01  0.565           0.01          0.01        0.05
# 1  P7         2018-04-01  0.374           < 0,01        0.066       0.14
# 2  P7         2018-07-01  3.493           < 0,01        0.172       0.14
# 3  P7         2018-10-01  2.326           < 0,01        0.063       < 0,05
# 0  P7         2018-01-01  0.565           0.01          0.01        0.05
# 1  P7         2018-04-01  0.374           < 0,01        0.066       0.14
# 2  P7         2018-07-01  3.493           < 0,01        0.172       0.14
# 3  P7         2018-10-01  2.326           < 0,01        0.063       < 0,05
# 0  P7         2019-01-10  1.336           0.01          0.064       0.05
# 1  P7         2019-04-11  3.579           <0,01         0.058       0.178
# 2  P7         2019-07-11  7.961           NaN           0.092       0.303
# 3  P7         2019-10-10  0.640           NaN           0.03        NaN
#
#   Cádmio Total Cianeto Cobalto Total Cobre Total Cromo Hexavalente  \
# 0  1            50      10            50          0.01
# 1  1            50      10            45          0.01
# 2  1            50      10            39.5        0.01
# 3  <0,001       <0,05   <0,01         <0,005      <0,01
# 0  <0,004       <0,005  <0,010        0.04        <0,0005
# 1  <0,004       <0,005  <0,010        0.077       <0,0005
# 2  <0,004       <0,005  <0,010        <0,0050     <0,0005
# 3  <0,004       <0,005  <0,010        <0,0050     <0,0005
# 0  <0,004       <0,005  <0,010        0.04        <0,0005
# 1  <0,004       <0,005  <0,010        0.077       <0,0005
# 2  <0,004       <0,005  <0,010        <0,0050     <0,0005
# 3  <0,004       <0,005  <0,010        <0,0050     <0,0005
# 0  < 0,004      0.005   < 0,010       0.042       < 0,0005
# 1  < 0,004      0.005   < 0,010       0.025       < 0,0005
# 2  <0,227       <0,005  <0,010        0.022       <0,0005
# 3  < 0,004      <0,005  < 0,010       0.105       < 0,0005
# 0  < 0,004      0.005   < 0,010       0.042       < 0,0005
# 1  < 0,004      0.005   < 0,010       0.025       < 0,0005
# 2  <0,227       <0,005  <0,010        0.022       <0,0005
# 3  < 0,004      <0,005  < 0,010       0.105       < 0,0005
# 0  0.004        0.05    0.01          0.02        0.02
# 1  < 0,004      < 0,05  < 0,01        < 0,01      < 0,02
# 2  < 0,004      < 0,02  < 0,01        0.061       < 0,02
# 3  < 0,004      < 0,02  < 0,01        0.072       0.012
# 0  0.004        0.05    0.01          0.02        0.02
# 1  < 0,004      < 0,05  < 0,01        < 0,01      < 0,02
# 2  < 0,004      < 0,02  < 0,01        0.061       < 0,02
# 3  < 0,004      < 0,02  < 0,01        0.072       0.012
# 0  0.004        0.02    0.01          0.059       0.02
# 1  <0,04        <0,02   <0,01         0.075       <0,02
# 2  NaN          NaN     NaN           0.057       NaN
# 3  NaN          NaN     NaN           0.025       NaN
#
#   Cromo Total Chumbo Total Estanho Total Índice de Fenóis  Ferro Total  \
# 0  10          10           10            0.02             223.000
# 1  10          10           10            0.02             896.000
# 2  10          10           10            0.02             2430.000
# 3  <0,01       <0,01        <0,01         <0,02            0.417
# 0  <0,009      <0,006       <0,050        NaN              0.856
# 1  <0,009      <0,006       <0,050        NaN              0.571
# 2  <0,009      <0,006       <0,050        NaN              1.220
# 3  <0,009      <0,006       <0,050        NaN              1.450
# 0  <0,009      <0,006       <0,050        NaN              0.856
# 1  <0,009      <0,006       <0,050        NaN              0.571
# 2  <0,009      <0,006       <0,050        NaN              1.220
# 3  <0,009      <0,006       <0,050        NaN              1.450
# 0  < 0,009     < 0,006      < 0,050       NaN              0.661
# 1  < 0,009     < 0,006      < 0,050       NaN              0.398
# 2  <0,009      <0,006       <0,050        NaN              0.213
# 3  < 0,009     < 0,006      < 0,050       NaN              0.312
# 0  < 0,009     < 0,006      < 0,050       NaN              0.661
# 1  < 0,009     < 0,006      < 0,050       NaN              0.398
# 2  <0,009      <0,006       <0,050        NaN              0.213
# 3  < 0,009     < 0,006      < 0,050       NaN              0.312
# 0  0.009       0.006        0.05          NaN              0.375
# 1  < 0,009     < 0,006      < 0,05        NaN              0.168
# 2  < 0,009     < 0,006      < 0,05        NaN              2.039
# 3  < 0,02      < 0,006      < 0,05        NaN              2.209
# 0  0.009       0.006        0.05          NaN              0.375
# 1  < 0,009     < 0,006      < 0,05        NaN              0.168
# 2  < 0,009     < 0,006      < 0,05        NaN              2.039
# 3  < 0,02      < 0,006      < 0,05        NaN              2.209
# 0  0.009       0.006        0.05          NaN              1.348
# 1  <0,009      <0,006       <0,05         NaN              4.052
# 2  NaN         NaN          NaN           NaN              3.446
# 3  NaN         NaN          NaN           NaN              0.128
#
#   Fluoreto Litio Total Manganês Total Mercúrio Total Molibdênio Total  \
# 0  1.47     10          67.6           0.075          10
# 1  3.71     10          83.9           0.075          10
# 2  8.69     10          76.5           0.08           10
# 3  0.15     <0,01       0.0173         <0,00008       <0,01
# 0  0.92     <0,090      0.03           <0,0001        <0,010
# 1  0.738    <0,090      0.019          <0,0001        <0,010
# 2  0.394    <0,090      0.134          <0,0001        <0,010
# 3  <0,05    <0,090      0.021          <0,1           <0,010
# 0  0.92     <0,090      0.03           <0,0001        <0,010
# 1  0.738    <0,090      0.019          <0,0001        <0,010
# 2  0.394    <0,090      0.134          <0,0001        <0,010
# 3  <0,05    <0,090      0.021          <0,1           <0,010
# 0  0.321    < 0,090     < 0,010        < 1,0          < 0,010
# 1  1.233    < 0,090     0.029          < 1,0          < 0,010
# 2  1.712    <0,090      <0,010         <1,0           <0,010
# 3  0.733    < 0,090     0.056          < 1,0          < 0,010
# 0  0.321    < 0,090     < 0,010        < 1,0          < 0,010
# 1  1.233    < 0,090     0.029          < 1,0          < 0,010
# 2  1.712    <0,090      <0,010         <1,0           <0,010
# 3  0.733    < 0,090     0.056          < 1,0          < 0,010
# 0  0.397    0.09        0.02           0.1            0.01
# 1  1.757    < 0,09      0.041          < 0,1          < 0,01
# 2  1.886    < 0,09      0.158          < 0,1          < 0,01
# 3  23.562   < 0,09      0.062          < 0,1          < 0,01
# 0  0.397    0.09        0.02           0.1            0.01
# 1  1.757    < 0,09      0.041          < 0,1          < 0,01
# 2  1.886    < 0,09      0.158          < 0,1          < 0,01
# 3  23.562   < 0,09      0.062          < 0,1          < 0,01
# 0  0.1      0.09        0.068          0.1            0.01
# 1  6.275    <0,09       0.129          <0,1           <0,1
# 2  2.313    NaN         0.126          NaN            NaN
# 3  1.103    NaN         NaN            NaN            NaN
#
#   Níquel Total Prata Total   Fenol
# 0  10           10          NaN
# 1  10           10          NaN
# 2  10           10          NaN
# 3  <0,01        <0,01       NaN
# 0  0.016        <0,010      <0,003
# 1  <0,010       <0,010      <0,01
# 2  <0,010       <0,010      <0,003
# 3  <0,010       <0,010      <0,1
# 0  0.016        <0,010      <0,003
# 1  <0,010       <0,010      <0,01
# 2  <0,010       <0,010      <0,003
# 3  <0,010       <0,010      <0,1
# 0  < 0,010      < 0,010     < 0,04
# 1  < 0,010      < 0,010     < 0,04
# 2  <0,010       <0,010      <0,04
# 3  < 0,010      < 0,010     < 0,04
# 0  < 0,010      < 0,010     < 0,04
# 1  < 0,010      < 0,010     < 0,04
# 2  <0,010       <0,010      <0,04
# 3  < 0,010      < 0,010     < 0,04
# 0  0.01         0.01        0.04
# 1  < 0,01       < 0,01      < 0,04
# 2  < 0,01       < 0,01      < 0,04
# 3  < 0,01       < 0,01      0.1
# 0  0.01         0.01        0.04
# 1  < 0,01       < 0,01      < 0,04
# 2  < 0,01       < 0,01      < 0,04
# 3  < 0,01       < 0,01      0.1
# 0  0.01         0.01        0.04
# 1  <0,1         <0,1        <0,04
# 2  NaN          NaN         0.02
# 3  NaN          NaN         NaN

# %%
df.to_csv(f"./Merged/{word}.csv", encoding='utf8', index=False)
copy2("cleaner.ipynb", f"./Logs/{word}.ipynb")
# Out:
# './Logs/toda_consema_2.ipynb'
