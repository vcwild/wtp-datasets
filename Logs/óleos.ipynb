# %%
import numpy as np 
import pandas as pd 
from os import listdir
from shutil import copy2 

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
path = "./Dataset/"
word = "óleos"
archives = listdir(path) 

matches = [value for value in archives if word in value]
matches = sorted(matches)
matches
# Out:
# ['óleos_e_graxas_2013.csv',
#  'óleos_e_graxas_2014.csv',
#  'óleos_e_graxas_2015.csv',
#  'óleos_e_graxas_2016.csv',
#  'óleos_e_graxas_2017.csv',
#  'óleos_e_graxas_2018.csv',
#  'óleos_e_graxas_2019.csv']

# %%
df = pd.DataFrame()
for i in range(0, len(matches) - 1):
    df_1 = pd.read_csv(path + matches[i], encoding='utf8')
    df_2 = pd.read_csv(path + matches[i + 1], encoding='utf8')
    partial = df_1.append(df_2)
    df = df.append(partial)

df
# Out:
#
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   O CBR estava paralizado neste dia, não havendo coleta nos pontos intermediários.
# 3   NaN
# 4   A coleta neste dia foi realizada no P6.
# 5   NaN
# 6   NaN
# 7   A coleta neste dia foi realizada no P6.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta neste dia foi realizada no P6, CBR parado.
# 0   NaN
# 1   NaN
# 2   O CBR estava paralizado neste dia, não havendo coleta nos pontos intermediários.
# 3   NaN
# 4   A coleta neste dia foi realizada no P6.
# 5   NaN
# 6   NaN
# 7   A coleta neste dia foi realizada no P6.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta neste dia foi realizada no P6, CBR parado.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
#
#    P7 - Rede Pluvial (trimestral)
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   24.3
# 1   NaN
# 2   NaN
# 3   <10,0
# 4   NaN
# 5   NaN
# 6   13
# 7   NaN
# 8   NaN
# 9   11.5
# 10  NaN
# 11  NaN
# 0   24.3
# 1   NaN
# 2   NaN
# 3   <10,0
# 4   NaN
# 5   NaN
# 6   13
# 7   NaN
# 8   NaN
# 9   11.5
# 10  NaN
# 11  NaN
# 0   <10,0
# 1   NaN
# 2   NaN
# 3   <10,0
# 4   NaN
# 5   NaN
# 6   19.7
# 7   NaN
# 8   NaN
# 9   19.4
# 10  NaN
# 11  NaN
# 0   <10,0
# 1   NaN
# 2   NaN
# 3   <10,0
# 4   NaN
# 5   NaN
# 6   19.7
# 7   NaN
# 8   NaN
# 9   19.4
# 10  NaN
# 11  NaN
# 0   18.6
# 1   NaN
# 2   NaN
# 3   19.1
# 4   NaN
# 5   NaN
# 6   16.8
# 7   NaN
# 8   NaN
# 9   <10
# 10  NaN
# 11  NaN
# 0   18.6
# 1   NaN
# 2   NaN
# 3   19.1
# 4   NaN
# 5   NaN
# 6   16.8
# 7   NaN
# 8   NaN
# 9   <10
# 10  NaN
# 11  NaN
# 0   NaN
# 1   14.4
# 2   NaN
# 3   <10
# 4   NaN
# 5   NaN
# 6   10.6
# 7   NaN
# 8   16.8
# 9   17.7
# 10  NaN
# 11  NaN
# 0   NaN
# 1   14.4
# 2   NaN
# 3   <10
# 4   NaN
# 5   NaN
# 6   10.6
# 7   NaN
# 8   16.8
# 9   17.7
# 10  NaN
# 11  NaN
# 0   14.8
# 1   NaN
# 2   NaN
# 3   24.5
# 4   NaN
# 5   NaN
# 6   15.5
# 7   NaN
# 8   NaN
# 9   <10
# 10  NaN
# 11  NaN

# %%
df.to_csv(f"./Merged/{word}.csv", encoding='utf8', index=False)
copy2("cleaner.ipynb", f"./Logs/{word}.ipynb")
# Out:
# './Logs/óleos.ipynb'
