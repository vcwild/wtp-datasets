# %%
import numpy as np 
import pandas as pd 
from os import listdir
from shutil import copy2 

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
path = "./Dataset/"
word = "sólidos"
archives = listdir(path) 

matches = [value for value in archives if word in value]
matches = sorted(matches)
matches
# Out:
# ['sólidos_2013.csv',
#  'sólidos_2014.csv',
#  'sólidos_2015.csv',
#  'sólidos_2016.csv',
#  'sólidos_2017.csv',
#  'sólidos_2018.csv',
#  'sólidos_2019.csv']

# %%
df = pd.DataFrame()
for i in range(0, len(matches) - 1):
    df_1 = pd.read_csv(path + matches[i], encoding='utf8')
    df_2 = pd.read_csv(path + matches[i + 1], encoding='utf8')
    partial = df_1.append(df_2)
    df = df.append(partial)

df
# Out:
#
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   A coleta neste dia foi realizada no P6, CBR parado.
# 5   NaN
# 6   NaN
# 7   A coleta neste dia foi realizada no P6, CBR parado.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta neste dia foi realizada no P6, CBR parado.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   A coleta neste dia foi realizada no P6, CBR parado.
# 5   NaN
# 6   NaN
# 7   A coleta neste dia foi realizada no P6, CBR parado.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta neste dia foi realizada no P6, CBR parado.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
#
#     P7 - Rede Pluvial (trimestral)
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0   10.9
# 1  NaN
# 2  NaN
# 3   4.2
# 4  NaN
# 5  NaN
# 6   112.2
# 7  NaN
# 8  NaN
# 9   11.5
# 10 NaN
# 11 NaN
# 0   10.9
# 1  NaN
# 2  NaN
# 3   4.2
# 4  NaN
# 5  NaN
# 6   112.2
# 7  NaN
# 8  NaN
# 9   11.5
# 10 NaN
# 11 NaN
# 0   10.3
# 1  NaN
# 2  NaN
# 3   40.7
# 4  NaN
# 5  NaN
# 6   7.7
# 7  NaN
# 8  NaN
# 9   12.8
# 10 NaN
# 11 NaN
# 0   10.3
# 1  NaN
# 2  NaN
# 3   40.7
# 4  NaN
# 5  NaN
# 6   7.7
# 7  NaN
# 8  NaN
# 9   12.8
# 10 NaN
# 11 NaN
# 0   5.6
# 1  NaN
# 2  NaN
# 3   3.7
# 4  NaN
# 5  NaN
# 6   28.6
# 7  NaN
# 8  NaN
# 9   6.4
# 10 NaN
# 11 NaN
# 0   5.6
# 1  NaN
# 2  NaN
# 3   3.7
# 4  NaN
# 5  NaN
# 6   28.6
# 7  NaN
# 8  NaN
# 9   6.4
# 10 NaN
# 11 NaN
# 0  NaN
# 1   6.2
# 2  NaN
# 3   12.0
# 4  NaN
# 5  NaN
# 6   4.3
# 7  NaN
# 8  NaN
# 9   26.1
# 10 NaN
# 11 NaN
# 0  NaN
# 1   6.2
# 2  NaN
# 3   12.0
# 4  NaN
# 5  NaN
# 6   4.3
# 7  NaN
# 8  NaN
# 9   26.1
# 10 NaN
# 11 NaN
# 0   1.4
# 1  NaN
# 2  NaN
# 3   11.8
# 4  NaN
# 5  NaN
# 6   11.5
# 7  NaN
# 8  NaN
# 9   2.3
# 10 NaN
# 11 NaN

# %%
df.to_csv(f"./Merged/{word}.csv", encoding='utf8', index=False)
copy2("cleaner.ipynb", f"./Logs/{word}.ipynb")
# Out:
# './Logs/ptel.ipynb'
