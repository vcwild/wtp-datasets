# %%
import numpy as np 
import pandas as pd 
from os import listdir
from shutil import copy2 


# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
path = "./Dataset/"
word = "compostagem"
archives = listdir(path) 

matches = [value for value in archives if word in value]
matches = sorted(matches)
matches
# Out:
# ['compostagem_2013.csv',
#  'compostagem_2014.csv',
#  'compostagem_2015.csv',
#  'compostagem_2016.csv',
#  'compostagem_2017.csv',
#  'compostagem_2018.csv',
#  'compostagem_2019.csv']

# %%
df = pd.DataFrame()
for i in range(0, len(matches) - 1):
    df_1 = pd.read_csv(path + matches[i], encoding='utf8')
    df_2 = pd.read_csv(path + matches[i + 1], encoding='utf8')
    partial = df_1.append(df_2)
    df = df.append(partial)

# %%
df
# Out:
#   DATA DA COLETA  UMIDADE % p/p  ALUMÍNIO (mg/kg)  COBRE (mg/kg)  \
# 0  2013-02-05    NaN            NaN               NaN
# 1  2013-05-07     64.70          2606.000          56.500
# 2  2013-08-06    NaN            NaN               NaN
# 3  2013-11-05     70.40          2249.000          207.000
# 0  2014-02-05     54.80          2606.000          56.500
# 1  2014-05-05     46.80          2245.000          60.400
# 2  2014-08-06     45.00          1599.000          23.800
# 3  2014-11-05     50.80          2249.000          36.000
# 0  2014-02-05     54.80          2606.000          56.500
# 1  2014-05-05     46.80          2245.000          60.400
# 2  2014-08-06     45.00          1599.000          23.800
# 3  2014-11-05     50.80          2249.000          36.000
# 0  2015-01-16     46.00          2800.000          122.000
# 1  2015-04-08     18.50          3790.000          18.300
# 2  2015-07-03     45.50          3510.000          15.800
# 3  2015-10-09     27.50          2730.000          19.500
# 0  2015-01-16     46.00          2800.000          122.000
# 1  2015-04-08     18.50          3790.000          18.300
# 2  2015-07-03     45.50          3510.000          15.800
# 3  2015-10-09     27.50          2730.000          19.500
# 0  2016-01-07     25.80          5128.000          26.200
# 1  2016-04-07     10.60          6352.000          22.500
# 2  2016-07-07     23.20          9975.600          26.200
# 3  2016-10-06     20.00          9246.200          10.800
# 0  2016-01-07     25.80          5128.000          26.200
# 1  2016-04-07     10.60          6352.000          22.500
# 2  2016-07-07     23.20          9975.600          26.200
# 3  2016-10-06     20.00          9246.200          10.800
# 0  2017-01-12     43.70          14740.200         211.600
# 1  2017-04-06     12.10          12764.000         14.030
# 2  2017-07-13     72.10          13862.000         182.000
# 3  2017-10-05     62.30          13285.000         46.300
# 0  2017-01-12     43.70          14740.200         211.600
# 1  2017-04-06     12.10          12764.000         14.030
# 2  2017-07-13     72.10          13862.000         182.000
# 3  2017-10-05     62.30          13285.000         46.300
# 0  2018-01-11     51.58          4387.876          24.960
# 1  2018-04-19     23.77          7466.135          11.554
# 2  2018-07-12     24.78          4692.582          17.057
# 3  2018-10-11     31.05          4278.903          27.811
# 0  2018-01-11     51.58          4387.876          24.960
# 1  2018-04-19     23.77          7466.135          11.554
# 2  2018-07-12     24.78          4692.582          17.057
# 3  2018-10-11     31.05          4278.903          27.811
# 0  2019-01-10     35.85          3875.636          15.252
# 1  2019-04-11     24.05          8114.786          202.918
# 2  2019-07-11     11.07          9582.837          37.346
# 3  2019-10-10     10.69          9743.689          29.515
#
#   CROMO (mg/kg)  MANGANÊS (mg/kg) NÍQUEL (mg/kg) LABORATÓRIO ALAC  \
# 0  NaN          NaN                NaN            x
# 1  16.4          63.400            8.18           x
# 2  NaN          NaN                NaN            x
# 3  NaN           41.300            17.4           x
# 0  17.4          43.400            8.18           x
# 1  11.8          12.500            2.82           x
# 2  6.2           123.000           10             x
# 3  7.8           41.300            17.4           x
# 0  17.4          43.400            8.18           x
# 1  11.8          12.500            2.82           x
# 2  6.2           123.000           10             x
# 3  7.8           41.300            17.4           x
# 0  10.5          14.000            5.5            NaN
# 1  12            169.000           4.58           NaN
# 2  11.9          257.000           5              NaN
# 3  8.51          150.000           3.27           NaN
# 0  10.5          14.000            5.5            NaN
# 1  12            169.000           4.58           NaN
# 2  11.9          257.000           5              NaN
# 3  8.51          150.000           3.27           NaN
# 0  8.3           147.800           8.5            NaN
# 1  12.3          180.000           8.5            NaN
# 2  14.8          178.300           8.5            NaN
# 3  11.2          161.800           8.5            NaN
# 0  8.3           147.800           8.5            NaN
# 1  12.3          180.000           8.5            NaN
# 2  14.8          178.300           8.5            NaN
# 3  11.2          161.800           8.5            NaN
# 0  25.6          70.000            18.5           NaN
# 1  25.16         179.900           8.5            NaN
# 2  36.4          64.800            18.7           NaN
# 3  21            176.000           8.5            NaN
# 0  25.6          70.000            18.5           NaN
# 1  25.16         179.900           8.5            NaN
# 2  36.4          64.800            18.7           NaN
# 3  21            176.000           8.5            NaN
# 0  < 8           225.832           < 8,5          NaN
# 1  13.347        184.861           < 8,5          NaN
# 2  < 8           173.146           < 8,5          NaN
# 3  10.131        200.238           < 8,5          NaN
# 0  < 8           225.832           < 8,5          NaN
# 1  13.347        184.861           < 8,5          NaN
# 2  < 8           173.146           < 8,5          NaN
# 3  10.131        200.238           < 8,5          NaN
# 0  8             243.449           8.5            NaN
# 1  28.794        58.755            8.56           NaN
# 2  19.865        242.352           8.5            NaN
# 3  15.728        225.437           ND             NaN
#
#                                                                               OBSERVAÇÕES  \
# 0  SGA solicita a ALAC relatório para este parâmetro, mas não obteve retorno. - Em 03/05
# 1  Lab. realizou a coleta em 26/06/2013
# 2  Lab. equivocadamente não realizou coleta do composto neste dia.
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
#
#    PORCENTAGEM DE SÓLIDOS % p/p  SÓLIDOS VOLÁTEIS % p/p LABORATÓRIO BIOAGRI  \
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0  54.0                          26.5                    x
# 1  80.5                          11.0                    x
# 2  54.0                          13.8                    x
# 3  72.5                          11.0                    x
# 0  54.0                          26.5                    x
# 1  80.5                          11.0                    x
# 2  54.0                          13.8                    x
# 3  72.5                          11.0                    x
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
# 0 NaN                           NaN                      NaN
# 1 NaN                           NaN                      NaN
# 2 NaN                           NaN                      NaN
# 3 NaN                           NaN                      NaN
#
#   COMPOSTOS ORGÂNICOS VOLÁTEIS  (µg/kg)
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 0  2
# 1  2
# 2  2
# 3  2
# 0  2
# 1  2
# 2  2
# 3  2
# 0  2
# 1  2
# 2  2
# 3  2
# 0  2
# 1  2
# 2  2
# 3  2
# 0  263.795
# 1  <2
# 2  <2
# 3  <2
# 0  263.795
# 1  <2
# 2  <2
# 3  <2
# 0  <2
# 1  <2
# 2  N.D.
# 3  69.45

# %%
df.to_csv(f"./Merged/{word}.csv", encoding='utf8', index=False)
copy2("cleaner.ipynb", f"./Logs/{word}.ipynb")
# Out:
# './Logs/compostagem.ipynb'
