# %%
import numpy as np 
import pandas as pd 
from os import listdir
from shutil import copy2 


# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
path = "./Dataset/"
word = "DBO"
archives = listdir(path) 

matches = [value for value in archives if word in value]
matches = sorted(matches)
matches
# Out:
# ['DBO_2013.csv',
#  'DBO_2014.csv',
#  'DBO_2015.csv',
#  'DBO_2016.csv',
#  'DBO_2017.csv',
#  'DBO_2018.csv',
#  'DBO_2019.csv']

# %%
df = pd.DataFrame()
for i in range(0, len(matches) - 1):
    df_1 = pd.read_csv(path + matches[i], encoding='utf8')
    df_2 = pd.read_csv(path + matches[i + 1], encoding='utf8')
    partial = df_1.append(df_2)
    df = df.append(partial)

df
# Out:
#
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   A coleta foi realizado no P6, CBR estava parado.
# 5   NaN
# 6   NaN
# 7   A coleta foi realizado no P6, CBR estava parado.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta foi realizado no P6, CBR estava parado.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   A coleta foi realizado no P6, CBR estava parado.
# 5   NaN
# 6   NaN
# 7   A coleta foi realizado no P6, CBR estava parado.
# 8   NaN
# 9   NaN
# 10  NaN
# 11  A coleta foi realizado no P6, CBR estava parado.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
#
#     P7 - Rede Pluvial (trimestral)
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 0   62.7
# 1  NaN
# 2  NaN
# 3   13.5
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9   10.3
# 10 NaN
# 11 NaN
# 0   62.7
# 1  NaN
# 2  NaN
# 3   13.5
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9   10.3
# 10 NaN
# 11 NaN
# 0   2.0
# 1  NaN
# 2  NaN
# 3   6.0
# 4  NaN
# 5  NaN
# 6   2.0
# 7  NaN
# 8  NaN
# 9   1.2
# 10 NaN
# 11 NaN
# 0   2.0
# 1  NaN
# 2  NaN
# 3   6.0
# 4  NaN
# 5  NaN
# 6   2.0
# 7  NaN
# 8  NaN
# 9   1.2
# 10 NaN
# 11 NaN
# 0   4.0
# 1  NaN
# 2  NaN
# 3   4.0
# 4  NaN
# 5  NaN
# 6   75.0
# 7  NaN
# 8  NaN
# 9   11.0
# 10 NaN
# 11 NaN
# 0   4.0
# 1  NaN
# 2  NaN
# 3   4.0
# 4  NaN
# 5  NaN
# 6   75.0
# 7  NaN
# 8  NaN
# 9   11.0
# 10 NaN
# 11 NaN
# 0  NaN
# 1   20.0
# 2  NaN
# 3   7.9
# 4  NaN
# 5  NaN
# 6   80.0
# 7  NaN
# 8  NaN
# 9   2.2
# 10 NaN
# 11 NaN
# 0  NaN
# 1   20.0
# 2  NaN
# 3   7.9
# 4  NaN
# 5  NaN
# 6   80.0
# 7  NaN
# 8  NaN
# 9   2.2
# 10 NaN
# 11 NaN
# 0   10.5
# 1  NaN
# 2  NaN
# 3   61.0
# 4  NaN
# 5  NaN
# 6   17.0
# 7  NaN
# 8  NaN
# 9   18.4
# 10 NaN
# 11 NaN

# %%
df.to_csv(f"./Merged/{word}.csv", encoding='utf8', index=False)
copy2("cleaner.ipynb", f"./Logs/{word}.ipynb")
# Out:
# './Logs/Cor_verdadeira.ipynb'
