# %% [markdown]
# # Análise Exploratória dos Dados
#
# ## Setup

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from math import inf
from shutil import copy2

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1)

# %%
# Read file
path = "./Tidy_Entities/"
name = "p1"
filename = name + ".csv"
df = pd.read_csv(path + filename, encoding='utf8')

# Transformations
df["DATE"] =  pd.to_datetime(df["DATE"], format="%Y-%m-%d")
df = df.sort_values("DATE").set_index("DATE")
df.drop(columns=["ENTIDADE"], inplace=True)

# %% [markdown]
# ## Verificar Informações do Dataset

# %%
df.dtypes
# Out:
# ALUMÍNIO                      float64
# ARSÊNIO                       float64
# BORO                          float64
# BÁRIO                         float64
# CHUMBO                        float64
# CIANETO                       float64
# COBALTO                       float64
# COBRE                         float64
# COLIFORMES_TERMOTOLERANTES    float64
# COR_VERDADEIRA                float64
# CROMO                         float64
# CROMO_HEXAVALENTE             float64
# CÁDMIO                        float64
# DBO                           float64
# DQO                           float64
# ESTANHO                       float64
# FENOL                         float64
# FERRO                         float64
# FLUORETO                      float64
# FÓSFORO                       float64
# LÍTIO                         float64
# MANGANÊS                      float64
# MERCÚRIO                      float64
# MOLIBDÊNIO                    float64
# NITROGÊNIO                    float64
# NITROGÊNIO_AMONIACAL          float64
# NITROGÊNIO_KJELDAHL           float64
# NÍQUEL                        float64
# PH                            float64
# PRATA                         float64
# SURFACTANTES                  float64
# SÓLIDOS                       float64
# ÍNDICE_DE_FENÓIS              float64
# ÓLEOS                         float64
# dtype: object

# %%
print(
    f"\033[31mLinhas: {df.shape[0]}\n"
    f"Colunas: {df.shape[1]}\n\n"
    f"\033[32m-> Features: \n{df.columns.tolist()}\n\n"
    f"\033[34m-> Valores ÚNICOS: \n{df.nunique().sort_values(ascending=False)}\n\n"
    f"\033[36m-> Valores FALTANTES: \n{df.isnull().sum().sort_values(ascending=True)}\033[0"
)
# Out:
# Linhas: 88
# Colunas: 34
#
# -> Features:
# ['ALUMÍNIO', 'ARSÊNIO', 'BORO', 'BÁRIO', 'CHUMBO', 'CIANETO', 'COBALTO', 'COBRE', 'COLIFORMES_TERMOTOLERANTES', 'COR_VERDADEIRA', 'CROMO', 'CROMO_HEXAVALENTE', 'CÁDMIO', 'DBO', 'DQO', 'ESTANHO', 'FENOL', 'FERRO', 'FLUORETO', 'FÓSFORO', 'LÍTIO', 'MANGANÊS', 'MERCÚRIO', 'MOLIBDÊNIO', 'NITROGÊNIO', 'NITROGÊNIO_AMONIACAL', 'NITROGÊNIO_KJELDAHL', 'NÍQUEL', 'PH', 'PRATA', 'SURFACTANTES', 'SÓLIDOS', 'ÍNDICE_DE_FENÓIS', 'ÓLEOS']
#
# -> Valores ÚNICOS:
# DQO                           86
# NITROGÊNIO                    82
# SÓLIDOS                       77
# DBO                           71
# FÓSFORO                       70
# ÓLEOS                         65
# SURFACTANTES                  63
# COLIFORMES_TERMOTOLERANTES    54
# ALUMÍNIO                      30
# MANGANÊS                      28
# NITROGÊNIO_AMONIACAL          27
# FERRO                         27
# BÁRIO                         25
# COR_VERDADEIRA                25
# NITROGÊNIO_KJELDAHL           23
# COBRE                         23
# FLUORETO                      21
# BORO                          16
# PH                            14
# FENOL                         14
# CROMO                         12
# NÍQUEL                        8
# CROMO_HEXAVALENTE             7
# CHUMBO                        7
# MERCÚRIO                      7
# ESTANHO                       6
# CIANETO                       6
# LÍTIO                         6
# MOLIBDÊNIO                    5
# ARSÊNIO                       5
# CÁDMIO                        4
# PRATA                         3
# COBALTO                       3
# ÍNDICE_DE_FENÓIS              2
# dtype: int64
#
# -> Valores FALTANTES:
# COLIFORMES_TERMOTOLERANTES    1
# DQO                           2
# FÓSFORO                       3
# NITROGÊNIO                    6
# SURFACTANTES                  7
# PH                            7
# DBO                           7
# ÓLEOS                         8
# SÓLIDOS                       8
# COR_VERDADEIRA                12
# MANGANÊS                      58
# ALUMÍNIO                      58
# BÁRIO                         58
# COBRE                         59
# FERRO                         60
# NITROGÊNIO_AMONIACAL          61
# NÍQUEL                        61
# LÍTIO                         61
# CROMO                         61
# FLUORETO                      62
# COBALTO                       63
# BORO                          63
# MOLIBDÊNIO                    64
# ARSÊNIO                       64
# NITROGÊNIO_KJELDAHL           65
# ESTANHO                       66
# CROMO_HEXAVALENTE             67
# CHUMBO                        67
# CÁDMIO                        68
# MERCÚRIO                      68
# CIANETO                       68
# FENOL                         68
# PRATA                         77
# ÍNDICE_DE_FENÓIS              84
# dtype: int64[0

# %% [markdown]
# ### Selecionar features com no mínimo 20% de valores VÁLIDOS || 80% NULOS

# %%
# Remove colunas com percentual de nulos acima do limite
aux = pd.DataFrame(df.isnull().sum() / df.shape[0], columns=["NULL_COUNT"])
null_ratio = .80 # limite
features = aux[aux["NULL_COUNT"] <= null_ratio].index.tolist()
filtered = df[features]

print(
    f"{df.shape[1] - df[features].shape[1]} colunas removidas:\n"
    f"{set(df.columns) - set(features)}\n"
)
# Out:
# 2 colunas removidas:
# {'ÍNDICE_DE_FENÓIS', 'PRATA'}

# %%
# Ordena os features por quantidade de nulos
threshold = (1 - df.isnull().sum() / df.shape[0]) 
threshold = pd.Series(np.around(threshold.values, 2), index=threshold.index)
threshold = threshold.sort_values(ascending=False)

# Plota o diff dos valores selecionados e excluídos
plt.figure(figsize=(5,2))
threshold.plot.bar(figsize=(8, 4))

# Insere barra horizontal no limiar dos features selecionados
plt.axhline(y=(1 - null_ratio), color="red", linewidth=1.5, linestyle="--")
plt.xticks(rotation=90)
plt.title("Percentual de Valores Válidos");

# %% [markdown]
# ## Análise de Séries Históricas
#
# ### Verificar valores faltantes na série histórica

# %%
df[threshold.index].plot(subplots=True, figsize=(10, 30));

# %% [markdown]
# ### Plotar séries históricas agregando por média anual, intervalo de confiança 95%

# %%
# Ordenando dados
ordered_columns = filtered.isnull().sum().sort_values(ascending=True).index
df_ordered = filtered[ordered_columns]
df_ordered["YEAR"] = [timestamp.year for timestamp in df_ordered.index]
cols = df_ordered.columns[:-1]
# Removendo ano de 2019 para validação do modelo de predição
validation = df_ordered.query("YEAR == 2019")
df_ordered.drop(labels=validation.index, axis=0, inplace=True)

# Plotando séries históricas
fig, axs = plt.subplots(len(cols), 1)
fig.set_figheight(100)

for key, col in enumerate(cols):
    sns.lineplot(
        data=df_ordered, 
        x="YEAR", 
        y=col, 
        estimator="mean",
        ci=95,
        n_boot=100, 
        ax=axs[key]
    );
# Out:
# NaN       NaN       NaN
# 2015-12-01 NaN       NaN       NaN       NaN    NaN       NaN       NaN
# 
# 2018-02-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-03-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-04-01  0.3240             0.050000  0.040000  0.1000    0.0040  2018
# 2018-05-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-06-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-07-01  0.0200             0.020000  2.300000  0.1000    0.0040  2018
# 2018-08-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-09-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-10-01  0.0250             0.020000  0.190000  0.1000    0.0040  2018
# 2018-11-01 NaN                NaN       NaN       NaN       NaN      2018
# 2018-12-01 NaN                NaN       NaN       NaN       NaN      2018

# %% [markdown]
# ### Identificando outliers nos dados agregados por ano

# %%
fig, axs = plt.subplots(len(cols), 1)
fig.set_figheight(60)

for key, col in enumerate(cols):
    g = sns.boxplot(
        data=df_ordered, 
        x="YEAR", 
        y=col,  
        ax=axs[key]
    )
    g.set_xlabel("");

# %% [markdown]
# ## Verificando a Distribuição dos Valores por Função Densidade
#
# ### Plotar Histograma e Estimativa de Densidade Kernel (KDE) removendo outliers
# <p style="text-align: center">
#     <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/3c55a119ef96b0901025a278e397fb8cb47ebc66" alt="equation" />
# </p>

# %%
fig, axs = plt.subplots(len(cols), 1)
fig.set_figheight(60)

for key, col in enumerate(cols):
    g = sns.distplot(
        a=df_ordered[col].dropna(),
        hist=True,
        kde=True, 
        ax=axs[key]
    )
    g.set_ylabel(col);

# %% [markdown]
# # Modelagem de Features
#
# ## Limitando Outliers
#
# ### Corrigindo outliers para os limites anuais de intervalo interquartil entre 25 e 75%

# %%
# Clipar cada outlier baseado no IQR anual da observação

# df_clipped = pd.DataFrame(columns=df_ordered.columns, index=df_ordered.index)
df_clipped = df_ordered.copy()

lower_boundary = df_ordered.groupby("YEAR").quantile(0.25)
lower_boundary.fillna(-inf, inplace=True)
upper_boundary = df_ordered.groupby("YEAR").quantile(0.75)
upper_boundary.fillna(inf, inplace=True)


years = df_ordered.index.year.unique().tolist()
cols = df_ordered.columns[:-1]

for col in cols:
    series = []
    for year in years:
        partial = df_ordered[df_ordered.index.year == year][col].clip(
            lower=lower_boundary[lower_boundary.index == year][col].values[0],
            upper=upper_boundary[upper_boundary.index == year][col].values[0]
        )

        series.append(partial)

    flattened = [val for sublist in series for val in sublist]
    df_clipped[col] = flattened

# Plotar boxplot anual de cada coluna
fig, axs = plt.subplots(len(cols), 1)
fig.set_figheight(60)

for key, col in enumerate(cols):
    g = sns.boxplot(
        data=df_clipped, 
        x="YEAR", 
        y=col,  
        ax=axs[key]
    )
    g.set_xlabel("");
# Out:
#             COLIFORMES_TERMOTOLERANTES    DQO  FÓSFORO  NITROGÊNIO  \
# DATE
# 2012-01-01  1254975.0                   170.0  2.4300  NaN
# 2012-03-01  1011200.0                   280.0  2.1925  NaN
# 2012-09-01  292400.0                    149.0  3.6500  NaN
# 2012-11-01  247297.5                    282.5  2.2200  NaN
# 2013-01-01  520315.0                    197.7  1.8750   25.075
#
#             SURFACTANTES   PH  DBO  ÓLEOS  SÓLIDOS  COR_VERDADEIRA  MANGANÊS  \
# DATE
# 2012-01-01 NaN           NaN  NaN  NaN    NaN      NaN              0.15400
# 2012-03-01 NaN           NaN  NaN  NaN    NaN      NaN              0.14675
# 2012-09-01 NaN           NaN  NaN  NaN    NaN      NaN              0.20725
# 2012-11-01 NaN           NaN  NaN  NaN    NaN      NaN              0.18100
# 2013-01-01  1.21          6.9 NaN  NaN    NaN       330.0          NaN
#
#             ALUMÍNIO   BÁRIO   COBRE    FERRO   CROMO   LÍTIO  NÍQUEL  \
# DATE
# 2012-01-01  0.26700   0.0340 NaN     NaN       185.00  0.0015  0.0165
# 2012-03-01  0.53100   0.0340  0.0230  0.02225  483.75  0.0025  0.0030
# 2012-09-01  0.90575   0.0440  0.0195 NaN       151.00  0.0020 NaN
# 2012-11-01  0.25775   0.0325  0.0220  0.02875  295.00 NaN      0.0030
# 2013-01-01 NaN       NaN     NaN     NaN      NaN     NaN     NaN
#
#             NITROGÊNIO_AMONIACAL  FLUORETO  COBALTO     BORO  ARSÊNIO  \
# DATE
# 2012-01-01  70.200               NaN       NaN      NaN       0.007
# 2012-03-01  73.000                0.041    NaN      NaN      NaN
# 2012-09-01  58.300               NaN        0.00175  0.92325 NaN
# 2012-11-01  75.275               NaN        0.00125  0.36975 NaN
# 2013-01-01 NaN                   NaN       NaN      NaN      NaN
#
#             MOLIBDÊNIO  NITROGÊNIO_KJELDAHL  ESTANHO  CHUMBO  \
# DATE
# 2012-01-01  0.002      NaN                   480.00  NaN
# 2012-03-01  0.004      NaN                   734.00  NaN
# 2012-09-01  0.002      NaN                   419.25  NaN
# 2012-11-01 NaN         NaN                   738.00  NaN
# 2013-01-01 NaN         NaN                  NaN      NaN
#
#             CROMO_HEXAVALENTE  CIANETO  FENOL  MERCÚRIO  CÁDMIO  YEAR
# DATE
# 2012-01-01 NaN                NaN      NaN    NaN       NaN      2012
# 2012-03-01  0.0025            NaN      NaN     0.043    NaN      2012
# 2012-09-01  0.0040            NaN      NaN    NaN       NaN      2012
# 2012-11-01  0.0040            NaN      NaN    NaN       NaN      2012
# 2013-01-01 NaN                NaN      NaN    NaN       NaN      2013

# %% [markdown]
# ### Série Histórica Corrigida

# %%
fig, axs = plt.subplots(len(cols), 1)
fig.set_figheight(100)

for key, col in enumerate(cols):
    sns.lineplot(
        data=df_clipped, 
        x="YEAR", 
        y=col, 
        estimator="mean",
        ci=95,
        n_boot=100, 
        ax=axs[key]
    );

# %% [markdown]
# ## Imputando média trimestral nos dados faltantes

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(
    missing_values=nan, 
    n_neighbors=2, 
    weights='uniform', 
    metric='nan_euclidean', 
    copy=True
)

imputer.fit()

# %% [markdown]
# ### Verificando Normalidade dos Dados Modelados
# Realizando o teste Shapiro-Wilk para verificar se os dados são provenientes de uma distribuição normal

# %%
from scipy.stats import shapiro 

test = []

for key, col in enumerate(cols): 
    test.append(shapiro(df_clipped[col].values))
shapiro(df_clipped[cols[1]].dropna().values)
# Out:
# (0.9732854962348938, 0.07148288190364838)

# %%
copy2("EDA.ipynb", f"./EDA/EDA_{name}.ipynb")
